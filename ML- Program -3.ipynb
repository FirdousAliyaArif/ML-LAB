# %%
#biuld Model With Linear Regression 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
np.random.seed(42)
x = np.random.rand(50,1)*100
print(x)
y = 3.58*x+np.random.randn(50,1)*20
model  = LinearRegression()
model.fit(x,y)
y_pred = model.predict(x)
plt.figure(figsize = (8,6))
plt.scatter(x,y, color = 'red', linewidths = 2, label = "Data")
plt.plot(x, y_pred, color = 'blue', label = 'Regression line')
plt.title('Linear Regression on random dataset')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# [[37.45401188]
#  [95.07143064]
#  [73.19939418]
#  [59.86584842]
#  [15.60186404]
#  [15.59945203]
#  [ 5.80836122]
#  [86.61761458]
#  [60.11150117]
#  [70.80725778]
#  [ 2.05844943]
#  [96.99098522]
#  [83.24426408]
#  [21.23391107]
#  [18.18249672]
#  [18.34045099]
#  [30.4242243 ]
#  [52.47564316]
#  [43.19450186]
#  [29.12291402]
#  [61.18528947]
#  [13.94938607]
#  [29.21446485]
#  [36.63618433]
#  [45.60699842]
#  [78.51759614]
#  [19.96737822]
#  [51.42344384]
#  [59.24145689]
#  [ 4.64504127]
#  [60.75448519]
#  [17.05241237]
#  [ 6.5051593 ]
#  [94.88855373]
#  [96.56320331]
#  [80.83973481]
#  [30.46137692]
#  [ 9.7672114 ]
#  [68.42330265]
#  [44.01524937]
#  [12.20382348]
#  [49.51769101]
#  [ 3.43885211]
#  [90.93204021]
#  [25.87799816]
#  [66.25222844]
#  [31.17110761]
#  [52.00680212]
#  [54.67102793]
#  [18.48544555]]
